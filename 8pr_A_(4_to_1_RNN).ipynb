# %% [markdown]
# ## A. (4-to-1 RNN) to show that the quantity of rain on a certain day also depends on the values of the previous day

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Define sequence of 50 days of rain data
rain_data = np.array([2.3, 1.5, 3.1, 2.0, 2.5, 1.7, 2.9, 3.5, 3.0, 2.1,
                      2.5, 2.2, 2.8, 3.2, 1.8, 2.7, 1.9, 3.1, 3.3, 2.0,
                      2.5, 2.2, 2.4, 3.0, 2.1, 2.5, 3.2, 3.1, 1.9, 2.7,
                      2.2, 2.8, 3.1, 2.0, 2.5, 1.7, 2.9, 3.5, 3.0, 2.1,
                      2.5, 2.2, 2.8, 3.2, 1.8, 2.7, 1.9, 3.1, 3.3, 2.0])

# Create input and output sequences for training
def create_sequences(values, time_steps):
    x = []
    y = []
    for i in range(len(values)-time_steps):
        x.append(values[i:i+time_steps])
        y.append(values[i+time_steps])
    return np.array(x), np.array(y)

time_steps = 4
x_train, y_train = create_sequences(rain_data, time_steps)

# Define RNN model
model = tf.keras.models.Sequential([
        tf.keras.layers.SimpleRNN(8, input_shape=(time_steps, 1)),
        tf.keras.layers.Dense(1)
        ])

# Compile model
model.compile(optimizer="adam", loss="mse")

# Train model
history = model.fit(x_train.reshape(-1, time_steps, 1), y_train, epochs=100)

# Plot loss over time
loss = history.history["loss"]
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, "bo", label="Training loss")
plt.title("Training loss")
plt.legend()
plt.show()

# Test model on new sequence
test_sequence = np.array([2.5, 2.2, 2.8, 3.2])
x_test = np.array([test_sequence])
y_test = model.predict(x_test.reshape(-1, time_steps, 1))

# Print input, output, and prediction
print("Previous days' rain data:", test_sequence)
print("Expected rain amount for next day:", y_test[0][0])
prediction = model.predict(np.array([test_sequence]).reshape(1, time_steps, 1))
print("Prediction:", prediction[0][0])
# Out:
# Epoch 1/100
# 2/2 [==============================] - 3s 27ms/step - loss: 2.0540
# Epoch 2/100
# 2/2 [==============================] - 0s 15ms/step - loss: 1.9797
# Epoch 3/100
# 2/2 [==============================] - 0s 16ms/step - loss: 1.9028
# Epoch 4/100
# 2/2 [==============================] - 0s 16ms/step - loss: 1.8314
# Epoch 5/100
# 2/2 [==============================] - 0s 14ms/step - loss: 1.7606
# Epoch 6/100
# 2/2 [==============================] - 0s 16ms/step - loss: 1.6942
# Epoch 7/100
# 2/2 [==============================] - 0s 19ms/step - loss: 1.6270
# Epoch 8/100
# 2/2 [==============================] - 0s 19ms/step - loss: 1.5650
# Epoch 9/100
# 2/2 [==============================] - 0s 17ms/step - loss: 1.5042
# Epoch 10/100
# 2/2 [==============================] - 0s 14ms/step - loss: 1.4432
# Epoch 11/100
# 2/2 [==============================] - 0s 13ms/step - loss: 1.3874
# Epoch 12/100
# 2/2 [==============================] - 0s 14ms/step - loss: 1.3325
# Epoch 13/100
# 2/2 [==============================] - 0s 29ms/step - loss: 1.2773
# Epoch 14/100
# 2/2 [==============================] - 0s 12ms/step - loss: 1.2231
# Epoch 15/100
# 2/2 [==============================] - 0s 23ms/step - loss: 1.1746
# Epoch 16/100
# 2/2 [==============================] - 0s 20ms/step - loss: 1.1260
# Epoch 17/100
# 2/2 [==============================] - 0s 18ms/step - loss: 1.0767
# Epoch 18/100
# 2/2 [==============================] - 0s 13ms/step - loss: 1.0328
# Epoch 19/100
# 2/2 [==============================] - 0s 14ms/step - loss: 0.9855
# Epoch 20/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.9445
# Epoch 21/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.9022
# Epoch 22/100
# 2/2 [==============================] - 0s 12ms/step - loss: 0.8610
# Epoch 23/100
# 2/2 [==============================] - 0s 14ms/step - loss: 0.8222
# Epoch 24/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.7877
# Epoch 25/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.7502
# Epoch 26/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.7151
# Epoch 27/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.6852
# Epoch 28/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6525
# Epoch 29/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.6231
# Epoch 30/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.5955
# Epoch 31/100
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5698
# Epoch 32/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.5462
# Epoch 33/100
# 2/2 [==============================] - 0s 14ms/step - loss: 0.5223
# Epoch 34/100
# 2/2 [==============================] - 0s 12ms/step - loss: 0.5006
# Epoch 35/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4818
# Epoch 36/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.4632
# Epoch 37/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.4465
# Epoch 38/100
# 2/2 [==============================] - 0s 13ms/step - loss: 0.4315
# Epoch 39/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.4163
# Epoch 40/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4056
# Epoch 41/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3923
# Epoch 42/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.3809
# Epoch 43/100
# 2/2 [==============================] - 0s 14ms/step - loss: 0.3725
# Epoch 44/100
# 2/2 [==============================] - 0s 12ms/step - loss: 0.3622
# Epoch 45/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.3553
# Epoch 46/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3467
# Epoch 47/100
# 2/2 [==============================] - 0s 13ms/step - loss: 0.3402
# Epoch 48/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.3342
# Epoch 49/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3284
# Epoch 50/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3238
# Epoch 51/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3201
# Epoch 52/100
# 2/2 [==============================] - 0s 14ms/step - loss: 0.3151
# Epoch 53/100
# 2/2 [==============================] - 0s 13ms/step - loss: 0.3123
# Epoch 54/100
# 2/2 [==============================] - 0s 13ms/step - loss: 0.3089
# Epoch 55/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.3063
# Epoch 56/100
# 2/2 [==============================] - 0s 13ms/step - loss: 0.3040
# Epoch 57/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.3016
# Epoch 58/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3006
# Epoch 59/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2984
# Epoch 60/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2971
# Epoch 61/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2956
# Epoch 62/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2946
# Epoch 63/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2935
# Epoch 64/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2927
# Epoch 65/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.2919
# Epoch 66/100
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2914
# Epoch 67/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2906
# Epoch 68/100
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2902
# Epoch 69/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2895
# Epoch 70/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2892
# Epoch 71/100
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2887
# Epoch 72/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2883
# Epoch 73/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.2879
# Epoch 74/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2876
# Epoch 75/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2873
# Epoch 76/100
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2870
# Epoch 77/100
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2866
# Epoch 78/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2864
# Epoch 79/100
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2861
# Epoch 80/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2858
# Epoch 81/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2855
# Epoch 82/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2852
# Epoch 83/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2850
# Epoch 84/100
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2848
# Epoch 85/100
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2845
# Epoch 86/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2843
# Epoch 87/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.2840
# Epoch 88/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2838
# Epoch 89/100
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2836
# Epoch 90/100
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2833
# Epoch 91/100
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2831
# Epoch 92/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2828
# Epoch 93/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2826
# Epoch 94/100
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2823
# Epoch 95/100
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2821
# Epoch 96/100
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2818
# Epoch 97/100
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2816
# Epoch 98/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2814
# Epoch 99/100
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2812
# Epoch 100/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2809
# 1/1 [==============================] - 0s 372ms/step
# Previous days' rain data: [2.5 2.2 2.8 3.2]
# Expected rain amount for next day: 2.6843915
# 1/1 [==============================] - 0s 42ms/step
# Prediction: 2.6843915
